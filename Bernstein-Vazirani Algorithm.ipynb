# %%
import qiskit
import numpy as np
from numpy import *

# %%
from qiskit import *
from qiskit.visualization import plot_histogram

# %%
secret = input("Enter a bit string: ")
qc = QuantumCircuit(len(secret)+1, len(secret))
qc.h(range(len(secret)))
qc.x(len(secret))
qc.h(len(secret))
qc.barrier()
#blackbox
for ii, yesno in enumerate(reversed(secret)):
    if yesno == '1':
       qc.cx(ii,len(secret))
qc.barrier()
qc.h(range(len(secret)))
qc.barrier()
qc.measure(range(len(secret)),range(len(secret)))
qc.draw('mpl')
# Out:
# Enter a number: 1000101010001

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, backend = simulator, shots = 1).result()
counts = result.get_counts()
print(counts)
# Out:
# {'1000101010001': 1}
